# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Kamurthi Ravi Teja__
#
# Doctoral student

# %% [markdown]
# _I am interested in data science because it combines math and statistics, specialized programming, advanced analytics, artificial intelligence (AI), and machine learning with specific subject matter expertise to uncover actionable insights hidden in an organization’s data. These insights can be used to guide decision making and strategic planning._

# %% [markdown]
# ### I am printing an ouput of an url in the 5th cell

# %%
print("I am printing the ouput of an url:https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=model-management-deployment")
# Out:
# I am printing the ouput of an url:https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=model-management-deployment

# %% [markdown]
# Here, I created an hyperlink to IBM cloud docs, and then created the bulleted and numb
# [IBM cloud docs](https://dataplatform.cloud.ibm.com/docs/content/wsj/getting-started/welcome-main.html?audience=wdp)
# - AWS
# - Azure
# - IBM
#
# 1. AWS
# 2. Azure
# 3. IBM
